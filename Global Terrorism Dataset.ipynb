# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Author -** Mohit Bisht

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The primary aim of this project is to perform an in-depth Exploratory Data Analysis (EDA) of the Global Terrorism Database (GTD), a publicly available dataset containing detailed information on both domestic and international terrorist incidents worldwide from 1970 to 2017. Managed by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, the database records over 180,000 terrorist events. The project intends to thoroughly examine this extensive dataset, uncover significant trends and patterns related to terrorist activities, and visually present these findings for better comprehension.
#
# A fundamental aspect of this project involves leveraging Python libraries optimized for data analysis and visualization. The Pandas library will serve as the cornerstone for tasks such as data loading, data cleaning, and complex aggregation operations, given its efficient data structures and handling of large datasets.
#
# For advanced numerical operations and faster computation, the project will utilize the NumPy library, which is proficient in managing multi-dimensional arrays and matrices, thus enhancing data processing capabilities.
#
# The project will go beyond numerical analysis, utilizing the Matplotlib and Seaborn libraries to create engaging and informative visualizations. By employing various visualization techniques, including bar plots, scatter plots, histograms, and heatmaps, the project aims to uncover relationships between variables and visually depict the dataset's characteristics.
#
# Through the exploration of the GTD, the project seeks to gain a comprehensive understanding of terrorism patterns spanning several decades. The objective is to identify potential trends in attack frequency, the most targeted countries, prevalent attack methods, types of weapons used, casualties, and the evolution of terrorist organizations, among other relevant aspects.
#
# By examining these factors, the project aspires to provide a comprehensive overview of global terrorism trends, which can contribute to the formulation of effective counter-terrorism strategies and policies. Additionally, the findings may offer insights into the characteristics of regions prone to attacks and the underlying reasons for their vulnerability.
#
# In summary, this project employs a data-driven approach to delve into the complex realm of terrorism, aiming to bring to light intricate patterns within the extensive GTD. The expected outcome of the project is a collection of valuable insights that can significantly contribute to ongoing counter-terrorism efforts and serve as a basis for future research in this field. Through a combination of data manipulation, numerical analysis, and visual representation, the project endeavors to conduct a comprehensive exploration of the dataset, leading to significant findings related to global terrorism.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Using exploratory data analysis (EDA) techniques on the GTD, identify the hot zones of terrorism globally and discern the evolving patterns of terrorist activities. What insights related to security issues can be derived from this analysis that could be instrumental in shaping counter-terrorism strategies?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to leverage the data contained within the Global Terrorism Database (GTD) to derive actionable insights into terrorist activities worldwide from 1970 to 2017. By conducting a comprehensive exploratory data analysis (EDA), the goal is to identify the key patterns, trends, and correlations related to global terrorism, thereby enabling better-informed decision-making for security analysts, policy-makers, and counter-terrorism agencies.
#
# Specifically, the objectives include:
#
# Identification of global "hot zones" for terrorist activities: By determining the most affected regions, we can better understand where resources might be best allocated to prevent future attacks.
#
# Analysis of frequency and intensity of attacks: Understanding how these have evolved over time can provide insights into the changing dynamics of terrorism and allow for more accurate risk assessments.
#
# Examination of methodologies and weapons used in attacks: This can shed light on the operational preferences of terrorist organizations and potentially provide early indicators of future threats.
#
# Assessment of casualty trends: This can help identify the most devastating types of attacks and allow for targeted response planning to minimize human loss.
#
# Unveiling patterns related to terrorist organizations: This can potentially aid in understanding their strategies, thereby supporting intelligence agencies in their counter-terrorism efforts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data_path = "/content/drive/MyDrive/Global Terrorism Data.csv"
df = pd.read_csv(data_path, encoding='ISO-8859-1')
# Out:
# <ipython-input-4-5c0ae58d7ea7>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, encoding='ISO-8859-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows, cols = df.shape
print(f'There are {rows} rows and {cols} columns in the dataset.')
# Out:
# There are 181691 rows and 135 columns in the dataset.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_rows = df.duplicated().sum()

print(f'There are {duplicate_rows} duplicate_rows in the dataset')
# Out:
# There are 0 duplicate_rows in the dataset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the missing values
missing = df.isnull()
plt.figure(figsize=(6, 4))
sns.heatmap(missing, cbar=False, cmap='viridis', yticklabels=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Dataset Size:** The dataset is quite large, containing 181,691 entries or rows.
#
# **Feature Quantity:** The dataset contains 135 features or columns.
#
# **Data Types:** The dataset has a mix of data types. There are 55 features with floating point numbers (float64), 22 features with integers (int64), and 58 features with objects (object). The object datatype in pandas typically means the column contains string (text) data.
#
# **Memory Usage:** The dataset uses over 187.1 MB of memory.
#
# **Missing Values:** There are some columns with a large number of missing values. For example, the 'approxdate' column has 172,452 missing values and the 'related' column has 156,653 missing values. However, several columns do not have any missing values, such as 'eventid', 'iyear', 'imonth', 'iday', 'INT_LOG', 'INT_IDEO', 'INT_MISC', and 'INT_ANY'.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = df.columns

print("Columns in the dataset")

for column in columns:
  print(column)
# Out:
# Columns in the dataset
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# ...

# %%
# Dataset Describe
summary = df.describe()

print(summary)
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# eventid: Unique ID for each event or terrorist attack.
#
# iyear: Year the terrorist attack occurred.
#
# imonth: Month the terrorist attack occurred.
#
# iday: Day the terrorist attack occurred.
#
# country_txt: Name of the country where the terrorist attack occurred.
#
# region_txt: Name of the region where the terrorist attack occurred.
#
# city: City where the terrorist attack occurred.
#
# attacktype1_txt: The general method of attack employed.
#
# target1: The specific person, building, installation, etc., that was targeted.
#
# nkill: Number of confirmed fatalities for the incident.
#
# nwound: Number of confirmed non-fatal injuries.
#
# gname: Name of the group that carried out the attack.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_countries = df['country_txt'].unique()
print(unique_countries)

print()  #this for leave a gap

unique_year = df['iyear'].unique()
print(unique_year)
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#Data type of the columns
print(df.dtypes)
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
pd.reset_option('display.max_rows')

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
data.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# This dataset contains 135 columns. They have a huge proportion of columns in dataset and Learning from them doesn't make any sense. So, we will rename some columns name for better understaning and then we will only extract renamed columns.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(15,7))
sns.countplot(data=data, x='Year')
plt.title('Count of terrorist activities each year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# A line plot was chosen because it provides an excellent visual representation of the trend over time.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# The insight that can be gained by the trend of terrorist activities over the years. We can see if the frequency of attacks is increasing, decreasing, or remaining stable before 2011, but after that it was increased.

# %% [markdown]
#  **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These discoveries play a pivotal role in forecasting future patterns, enabling law enforcement and security agencies to allocate resources and develop effective strategies. Nonetheless, an upward trend in terrorist activities could have adverse implications, signaling an escalating issue.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(15,7))
sns.lineplot(data=data, x='Year', y='Killed', estimator='sum')
plt.title('Number of people killed by terror attack')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# A line plot was chosen to observe the trend of casualties over time.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# The insight is the severity of terrorist activities over the years in terms of human lives lost.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# This could influence policy making, disaster management planning, insurance, and healthcare provisions. An increasing trend could lead to negative growth by discouraging population stability, investment, and development.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(15,7))
sns.countplot(data=data, x='AttackType')
plt.title('Attack types')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
#  A bar plot is used to compare the frequencies of different categories - in this case, attack types.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# We can learn about the most commonly used methods in terrorist attacks.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# These insights can help in developing and implementing measures to prevent and respond to these specific types of attacks. If certain types of attacks are prevalent, it may signify a failure to adequately address those threats, possibly leading to negative impacts.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(15,7))
sns.countplot(data=data, x='Region')
plt.title('Count of terrorist activities by region')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# A bar plot is suitable for categorical data and helps in comparing the number of terrorist activities in each region.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# We can see which regions experience the most terrorist activities, providing insight into geographical hotspots of terrorism.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# This information is useful for focusing resources and counter-terrorism efforts on the most affected areas. A high frequency of attacks in a particular region could discourage investment and tourism, leading to negative growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(15,7))

# Get the count of each group
group_data = data[data['Group'] != 'Unknown']['Group'].value_counts().head(10)

# Use this count for plotting
sns.barplot(x=group_data.index, y=group_data.values)

plt.title('Top 10 terrorist groups with highest no of attacks')
plt.xticks(rotation=90)
plt.xlabel('Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# A bar plot is suitable for finding the top 10 terriorist groups with highest no of attacks.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# We can identify which groups are responsible for the most terrorist activities.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# This information could be important for intelligence agencies in prioritizing threats and focusing their counter-terrorism efforts. If a particular group is increasingly active, it could contribute to instability and negative growth.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# **What do you suggest the client to achieve Business Objective ?**

# %% [markdown]
# Based on the findings from the exploratory data analysis conducted on the Global Terrorism Dataset, various recommendations can be made to a client interested in utilizing this information to mitigate the impact of terrorism and achieve the specified business goals.
#
# Emphasize High-Risk Regions: Priority should be given to regions experiencing the highest frequencies of terrorist activities. These areas might require enhanced security measures, targeted socioeconomic initiatives to address the underlying causes of terrorism, or increased international support.
#
# Monitor Annual Trends: Monitoring the fluctuation of terrorist incidents over the years can aid in predicting potential future threats and adjusting counter-terrorism strategies accordingly.
#
# Focus on Key Threat Groups: Our analysis indicates the prevalence of certain terrorist groups over others. Intelligence efforts should concentrate on these significant threat groups to proactively prevent future attacks.
#
# Address Common Attack Types: Understanding the most prevalent forms of terrorist attacks can assist in developing preemptive measures and response tactics. For example, if bombings are the primary attack type, allocating more resources to bomb detection and disposal may be necessary.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis (EDA) performed on the Global Terrorism Dataset yielded valuable insights into global terrorism trends and patterns spanning the years 1970 to 2017. Utilizing Python libraries such as Pandas, Matplotlib, Seaborn, and NumPy, we effectively managed, visualized, and interpreted intricate data pertaining to terrorist activities.
#
# This analysis enabled us to uncover temporal trends, identify high-risk regions, recognize prominent terrorist groups, and understand prevalent modes of attack. These findings are instrumental in the development of effective counter-terrorism strategies and interventions.
#
# The project underscored the significance of data-driven decision-making, as it facilitated the transformation of raw data into meaningful insights. Recognizing the vulnerability of specific regions to terrorist attacks or the heightened activities of certain terrorist groups allows for the more efficient allocation of resources by security agencies and policymakers, potentially safeguarding lives and assets.
#
# However, it is essential to recognize that combating terrorism necessitates a holistic approach that incorporates real-time intelligence, geopolitical complexities, and practical on-ground considerations.
#
# In conclusion, this project highlights the potential of data analysis in guiding and shaping counter-terrorism initiatives. It serves as a valuable foundation for further research and action, emphasizing the ongoing importance of data collection, analysis, and interpretation in addressing global security challenges, including terrorism.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
